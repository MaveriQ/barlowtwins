# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams.update({'font.size': 20})

# %%
def process_data(filename):
    model_lars = pd.read_csv(filename, usecols=['epoch','step','STSBenchmark','SICKRelatedness'])
#     model_lars = pd.read_csv(filename, usecols=['epoch','step','STSBenchmark','SICKRelatedness','STS12','STS13','STS14','STS15','STS16'])
    if model_lars.step.dtype=='object':
        model_lars.step = model_lars.step.apply(lambda x: x.replace('.ckpt','')).astype('int32')
    else:
        model_lars.step = model_lars.step.astype('int32')

    model_lars = model_lars.reindex(model_lars.sort_values(by=['epoch','step']).index,axis=0).reset_index(drop=True)

    model_lars = model_lars.reindex(['epoch','step','STS12','STS13','STS14','STS15','STS16','STSBenchmark','SICKRelatedness'],axis=1)
    
    fig, ax = plt.subplots(1,2)
    fig.set_size_inches(20, 10)
    ax[0].plot(model_lars.step,model_lars.SICKRelatedness)
    ax[1].plot(model_lars.step,model_lars.STSBenchmark);
    ax[0].legend(['SICKRelatedness'],prop={'size': 18})
    ax[1].legend(['STSBenchmark'], prop={'size': 18});
    
#     return model_lars

# %%
model_lars = process_data('bert_frozen_bs1024_dropout0.1_lr1e-3_lambd1e-3_mlm0_gpus4_mean_all_fp16_l_a_r_s.csv')

# %%
model_768 = process_data('bert_frozen_bs1024_dropout0.1_lr1e-3_lambd1e-3_mlm0_gpus4_mean_all_fp16_768-768-768.csv')

# %%
model_2048 = process_data('bert_frozen_bs1024_dropout0.1_lr1e-3_lambd1e-3_mlm0_gpus4_mean_all_fp16_2048-2048-2048.csv')

# %%
model_trainable = process_data('bert_trainable_bs32_dropout0.1_lr1e-3_lambd1e-3_mlm0_gpus8_mean_all_fp16_lars_l_a_r_s.csv')

# %% [markdown]
# ## Model_768_LARS

# %%
model_768_lars = process_data('bert_frozen_bs1024_dropout0.1_lr1e-3_lambd1e-3_mlm0_gpus4_mean_all_768-768-768_lars.csv')

# %% [markdown]
# ## Model_2048_LARS

# %%
model_2048_lars = process_data('bert_frozen_bs1024_dropout0.1_lr1e-3_lambd1e-3_mlm0_gpus4_mean_all_2048-2048-2048_lars.csv')

# %%
model_mlm_05 = process_data('bert_trainable_do-mlm_bs16_dropout0.1_lr1e-3_lambd1e-3_mlm_weight0.5_mlm0.1_gpus4_mean_20mil_fp16_lars.csv')

# %%
model_mlm_40 = process_data('bert_trainable_do-mlm_bs16_dropout0.1_lr1e-3_lambd1e-3_mlm_weight4.0_mlm0.1_gpus4_mean_20mil_fp16_lars.csv')

# %% [markdown]
# ## RESULTS 8 Sep

# %%
model_2048_5 = process_data('bert_frozen_2048-2048-2048-2048-2048_gpus2.csv')

# %%
model_4096_2 = process_data('bert_frozen_4096-4096_gpus2.csv')

# %%
model_4096_4 = process_data('bert_frozen_4096-4096-4096-4096_gpus2.csv')

# %%
model_2048_2_sim = process_data('bert_frozen_2048-2048_gpus2_sim_lambdasim10.0.csv')

# %%
model_all = process_data('old_results/bert_frozen_bs512_accum2_4096-4096_gpus2_allhidden_20mil.csv')

# %%
model_8192 = process_data('bert_frozen_8192-8192_gpus2.csv')

# %%
model_16382 = process_data('bert_frozen_16384-16384_bs512.csv')

# %% [markdown]
# ## Sep 15

# %%
model_allhidden_4096 = process_data('bert_frozen_bs512_accum2_4096-4096_gpus2_allhidden_20mil.csv')

# %%
model_nlpmixer12 = process_data('bert_nlpmixer12_bs32_gpus3_20mil.csv')

# %%
model_nlpmixer6 = process_data('bert_nlpmixer6_bs32_gpus4_all.csv')

# %%
model_nlpmixer6_4096_2 = process_data('old_results/bert_nlpmixer6_4096-4096_lamb1.0_gpus4_alldata_allhidden_bn.csv')

# %%
model_nlpmixer6_4096_2_100 = process_data('old_results/bert_nlpmixer6_4096-4096_lamb1.0_gpus2_alldata_allhidden_bn2.csv')

# %%
model_nlpmixer6_2048_2 = process_data('bert_nlpmixer6_2048-2048_lamb1.0_gpus1_20mil_allhidden_bn.csv')

# %%
model_nlpmixer6_2048_4 = process_data('bert_nlpmixer6_2048-2048-2048-2048_lamb1.0_gpus1_20mil_allhidden_bn.csv')

# %% [markdown]
# # TEST Set

# %%
model_nlpmixer6_4096_2_100 = process_data('bert_nlpmixer6_4096-4096_lamb1.0_gpus2_alldata_allhidden_bn2.csv')

# %%
model_nlpmixer6_2048_4 = process_data('bert_nlpmixer6_2048-2048-2048-2048_lamb1.0_gpus1_20mil_allhidden_bn.csv')

# %%
model_nlpmixer6_4096_2 = process_data('bert_nlpmixer6_4096-4096_lamb1.0_gpus4_alldata_allhidden_bn.csv')

# %%
process_data('bert_vicreg_trainable3_bs16_seq256_proj4096_2_data10ml.csv');

# %%
process_data('bert_vicreg_trainable3_bs32_seq128_proj4096_2_data10ml.csv');

# %%
process_data('bert_sota_trainable3_bs32_seq128_20mil_proj8192_2.csv');

# %%
process_data('bert_sota_trainable3_bs32_seq128_proj4096_2.csv');

# %%
process_data('bert_sota_trainable3_bs32_seq128_20mil_lamcorr1.0_proj4096_2.csv');

# %%
process_data('bert_trainable3_bs32_lamcorr1.0_74mil_8192_2_1cycle_gpus4_run2.csv')

# %%
process_data('bert_trainable3_bs32_lamcorr1.0_74mil_8192_2_run2.csv')

# %%
process_data('bert_trainable3_bs32_74mil_4096_2_1cycle_run2.csv')

# %%
process_data('bert_trainable3_bs32_1mil_4096_2_1cycle_seq32.csv')

# %%
process_data('bert_trainable3_bs32_1mil_4096_2_1cycle_seq64.csv')

# %%
process_data('bert_trainable3_bs16_accum2_1mil_seq256_1cycle_4096_2.csv')

# %%
process_data('bert_trainable3_bs32_5mil_8192_2_1cycle_seq32.csv')

# %%
process_data('bert_trainable3_bs32_lamcorr1.0_74mil_8192_2_1cycle_gpus4_run2.csv')

# %%
process_data('bert_trainable6_bs32_10mil_8192_2_1cycle_gpus4.csv')

# %%
process_data('bert_trainable4_bs32_1mil_seq128_1cycle_4096_2.csv')

# %%
process_data('bert_trainable4_bs32_10mil_8192_2_1cycle_gpus4.csv')

# %%
process_data('bert_vicreg2_trainable3_bs32_5mil_4096_2_skipsched_onlybarlow.csv')

# %%
process_data('bert_vicreg2_trainable3_bs32_5mil_4096_2_1cycle_onlybarlo.csv')

# %%
process_data('bert_vicreg2_trainable3_bs32_5mil_4096_2_skipsched_cov1mean_var0_mse0.csv')

# %%
process_data('bert_vicreg2_trainable3_bs32_5mil_4096_2_1cycle_cov1mean_var0_mse0.csv')

# %%
process_data('bert_vicreg2_trainable3_bs32_5mil_4096_2_skipsched_cov1mean_var1_mse1.csv')

# %%
process_data('bert_vicreg2_trainable3_bs32_5mil_4096_2_1cycle_cov1mean_var1_mse1.csv')

# %%
process_data('bert_vicreg2_trainable3_bs32_5mil_4096_2_skipsched_skipbarlow_cov1mean_var1_mse1.csv')

# %%
process_data('bert_vicreg2_trainable3_bs32_5mil_4096_2_1cycle_skipbarlow_cov1mean_var1_mse1.csv')

# %%
process_data('bert_vicreg2_trainable3_bs32_5mil_4096_2_skipsched_skipbarlow_cov1000mean_var1_mse1_gpus2.csv')

# %%
process_data('bert_vicreg2_trainable3_bs32_5mil_4096_2_skipsched_cov1mean_var0_mse0.csv')

# %%
process_data('bert_vicreg2_trainable3_bs32_5mil_4096_2_1cycle_cov0_var0_mse0.1.csv')

# %%
process_data('bert_vicreg2_trainable3_bs32_5mil_4096_2_skipsched_cov1e4mean_var1_mse1.csv')

# %%
process_data('bert_vicreg2_trainable3_bs32_5mil_4096_2_skipsched_cov0_var100_mse0.csv')

# %%
process_data('bert_vicreg2_trainable3_bs32_5mil_4096_2_skipsched_cov1000_var0_mse0.csv')
